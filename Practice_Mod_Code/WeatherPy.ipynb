# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime

# %%
#create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#create a list for holding the cities.
cities = []
#identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #if the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 602

# %%
#create empty list to hold the weather data
city_data = []
#print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("-------------------------------")

#create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -------------------------------

# %% [markdown]
# #loop through all the cities in our list.
# for i in range(len(cities)):
#
#     #group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)
#
#     #create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]

# %%
#import request library
import requests
#import API key
from config import weather_api_key

#starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#loop through all the cities in the list.
for i, city in enumerate(cities):

    #group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    #create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    #log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    #run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | tateyama
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | lata
# Processing Record 9 of Set 1 | moyale
# Processing Record 10 of Set 1 | los llanos de aridane
# Processing Record 11 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | komsomolskiy
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | pangnirtung
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | timmins
# Processing Record 19 of Set 1 | bolivar
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 1 | klaksvik
# Processing Record 24 of Set 1 | wanning
# Processing Record 25 of Set 1 | prince rupert
# Processing Record 26 of Set 1 | qaqortoq
# Processing Record 27 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 1 | pierre
# Processing Record 29 of Set 1 | labuhan
# Processing Record 30 of Set 1 | mount isa
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | cabo san lucas
# Processing Record 34 of Set 1 | aykhal
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | vangaindrano
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | kem
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 1 | alexandria
# Processing Record 48 of Set 1 | iracoubo
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 2 | solnechnyy
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | kutina
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | ternate
# Processing Record 7 of Set 2 | hami
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | tessalit
# Processing Record 10 of Set 2 | honiara
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | neiafu
# Processing Record 13 of Set 2 | coquimbo
# Processing Record 14 of Set 2 | salitral
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | nouadhibou
# Processing Record 18 of Set 2 | alofi
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | iqaluit
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | rincon
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | sao joao da barra
# Processing Record 25 of Set 2 | rumphi
# Processing Record 26 of Set 2 | san quintin
# Processing Record 27 of Set 2 | bukene
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | zelenets
# Processing Record 30 of Set 2 | chokurdakh
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | shache
# Processing Record 33 of Set 2 | asau
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | olhao
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | along
# Processing Record 38 of Set 2 | menongue
# Processing Record 39 of Set 2 | rabo de peixe
# Processing Record 40 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 2 | bandar
# Processing Record 42 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 2 | omsukchan
# Processing Record 44 of Set 2 | tilichiki
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | ilorin
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | nuuk
# Processing Record 49 of Set 2 | shubarshi
# Processing Record 50 of Set 2 | mount darwin
# Processing Record 1 of Set 3 | nome
# Processing Record 2 of Set 3 | westport
# Processing Record 3 of Set 3 | camana
# Processing Record 4 of Set 3 | perth
# Processing Record 5 of Set 3 | bafq
# Processing Record 6 of Set 3 | simbahan
# Processing Record 7 of Set 3 | devils lake
# Processing Record 8 of Set 3 | den helder
# Processing Record 9 of Set 3 | auki
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | leh
# Processing Record 12 of Set 3 | bozhou
# Processing Record 13 of Set 3 | souillac
# Processing Record 14 of Set 3 | vastseliina
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | lavrentiya
# Processing Record 18 of Set 3 | puerto baquerizo moreno
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | valparaiso
# Processing Record 21 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | sao filipe
# Processing Record 24 of Set 3 | batemans bay
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | buckeye
# Processing Record 27 of Set 3 | caruray
# Processing Record 28 of Set 3 | padang
# Processing Record 29 of Set 3 | high level
# Processing Record 30 of Set 3 | sola
# Processing Record 31 of Set 3 | aloleng
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | sept-iles
# Processing Record 34 of Set 3 | urengoy
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | katima mulilo
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | vardo
# Processing Record 40 of Set 3 | nadym
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | dalnerechensk
# Processing Record 43 of Set 3 | nanortalik
# Processing Record 44 of Set 3 | mount gambier
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | poronaysk
# Processing Record 47 of Set 3 | meulaboh
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | praia da vitoria
# Processing Record 50 of Set 3 | tomatlan
# Processing Record 1 of Set 4 | vaini
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | constitucion
# Processing Record 5 of Set 4 | yeppoon
# Processing Record 6 of Set 4 | port lincoln
# Processing Record 7 of Set 4 | cayenne
# Processing Record 8 of Set 4 | geraldton
# Processing Record 9 of Set 4 | kavieng
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | port blair
# Processing Record 12 of Set 4 | dunedin
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | turukhansk
# Processing Record 15 of Set 4 | cabedelo
# Processing Record 16 of Set 4 | sinnamary
# Processing Record 17 of Set 4 | shaunavon
# Processing Record 18 of Set 4 | dabola
# Processing Record 19 of Set 4 | wiwili
# Processing Record 20 of Set 4 | ambilobe
# Processing Record 21 of Set 4 | charters towers
# Processing Record 22 of Set 4 | santa maria
# Processing Record 23 of Set 4 | conceicao do araguaia
# Processing Record 24 of Set 4 | cedar city
# Processing Record 25 of Set 4 | laguna
# Processing Record 26 of Set 4 | iquitos
# Processing Record 27 of Set 4 | mettur
# Processing Record 28 of Set 4 | saskylakh
# Processing Record 29 of Set 4 | saint george
# Processing Record 30 of Set 4 | kijang
# Processing Record 31 of Set 4 | tumbes
# Processing Record 32 of Set 4 | cayeli
# Processing Record 33 of Set 4 | tabuk
# Processing Record 34 of Set 4 | kununurra
# Processing Record 35 of Set 4 | terebovlya
# Processing Record 36 of Set 4 | okhotsk
# Processing Record 37 of Set 4 | mahebourg
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | port macquarie
# Processing Record 41 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 4 | pochutla
# Processing Record 43 of Set 4 | marawi
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | chabahar
# Processing Record 46 of Set 4 | comodoro rivadavia
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | college
# Processing Record 49 of Set 4 | saint-pierre
# Processing Record 50 of Set 4 | nishihara
# Processing Record 1 of Set 5 | goderich
# Processing Record 2 of Set 5 | kings mountain
# Processing Record 3 of Set 5 | richards bay
# Processing Record 4 of Set 5 | sitka
# Processing Record 5 of Set 5 | sinazongwe
# Processing Record 6 of Set 5 | mitsamiouli
# Processing Record 7 of Set 5 | monteagudo
# Processing Record 8 of Set 5 | bijie
# Processing Record 9 of Set 5 | krasnoarmeysk
# Processing Record 10 of Set 5 | kushima
# Processing Record 11 of Set 5 | awjilah
# Processing Record 12 of Set 5 | new norfolk
# Processing Record 13 of Set 5 | taiyuan
# Processing Record 14 of Set 5 | bambous virieux
# Processing Record 15 of Set 5 | salamiyah
# Processing Record 16 of Set 5 | miri
# Processing Record 17 of Set 5 | fortuna
# Processing Record 18 of Set 5 | hornepayne
# Processing Record 19 of Set 5 | lagoa
# Processing Record 20 of Set 5 | izmir
# Processing Record 21 of Set 5 | bethel
# Processing Record 22 of Set 5 | vila franca do campo
# Processing Record 23 of Set 5 | la paz
# Processing Record 24 of Set 5 | buenos aires
# Processing Record 25 of Set 5 | pevek
# Processing Record 26 of Set 5 | san carlos de bariloche
# Processing Record 27 of Set 5 | roma
# Processing Record 28 of Set 5 | sooke
# Processing Record 29 of Set 5 | lompoc
# Processing Record 30 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 5 | kortkeros
# Processing Record 32 of Set 5 | kumluca
# Processing Record 33 of Set 5 | dmytrivka
# Processing Record 34 of Set 5 | dehloran
# Processing Record 35 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 5 | washington
# Processing Record 37 of Set 5 | srednekolymsk
# Processing Record 38 of Set 5 | georgetown
# Processing Record 39 of Set 5 | praia
# Processing Record 40 of Set 5 | salta
# Processing Record 41 of Set 5 | sanmenxia
# Processing Record 42 of Set 5 | kieta
# Processing Record 43 of Set 5 | yakeshi
# Processing Record 44 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 5 | cairns
# Processing Record 46 of Set 5 | staryy nadym
# Processing Record 47 of Set 5 | adrar
# Processing Record 48 of Set 5 | bria
# Processing Record 49 of Set 5 | wanaka
# Processing Record 50 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 6 | rostaq
# City not found. Skipping...
# Processing Record 2 of Set 6 | ilulissat
# Processing Record 3 of Set 6 | skibbereen
# Processing Record 4 of Set 6 | krasavino
# Processing Record 5 of Set 6 | emerald
# Processing Record 6 of Set 6 | winnemucca
# Processing Record 7 of Set 6 | kisangani
# Processing Record 8 of Set 6 | yumen
# Processing Record 9 of Set 6 | moron
# Processing Record 10 of Set 6 | tamiahua
# Processing Record 11 of Set 6 | staryy biser
# City not found. Skipping...
# Processing Record 12 of Set 6 | aklavik
# Processing Record 13 of Set 6 | san juan del sur
# Processing Record 14 of Set 6 | caravelas
# Processing Record 15 of Set 6 | clarence town
# Processing Record 16 of Set 6 | shingu
# Processing Record 17 of Set 6 | wajir
# Processing Record 18 of Set 6 | muisne
# Processing Record 19 of Set 6 | beira
# Processing Record 20 of Set 6 | rabaul
# Processing Record 21 of Set 6 | cap-aux-meules
# Processing Record 22 of Set 6 | san patricio
# Processing Record 23 of Set 6 | cherskiy
# Processing Record 24 of Set 6 | makakilo city
# Processing Record 25 of Set 6 | bassar
# Processing Record 26 of Set 6 | grabouw
# Processing Record 27 of Set 6 | novoilinsk
# Processing Record 28 of Set 6 | naze
# Processing Record 29 of Set 6 | mar del plata
# Processing Record 30 of Set 6 | tuatapere
# Processing Record 31 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 32 of Set 6 | oistins
# Processing Record 33 of Set 6 | namibe
# Processing Record 34 of Set 6 | umm lajj
# Processing Record 35 of Set 6 | loma bonita
# Processing Record 36 of Set 6 | avera
# Processing Record 37 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 6 | najran
# Processing Record 39 of Set 6 | sutton
# Processing Record 40 of Set 6 | omboue
# Processing Record 41 of Set 6 | yar-sale
# Processing Record 42 of Set 6 | esperance
# Processing Record 43 of Set 6 | vasteras
# Processing Record 44 of Set 6 | lorengau
# Processing Record 45 of Set 6 | blankenberge
# Processing Record 46 of Set 6 | coihaique
# Processing Record 47 of Set 6 | vredendal
# Processing Record 48 of Set 6 | bathsheba
# Processing Record 49 of Set 6 | santa cruz de la palma
# Processing Record 50 of Set 6 | burica
# City not found. Skipping...
# Processing Record 1 of Set 7 | bara
# Processing Record 2 of Set 7 | bonfim
# Processing Record 3 of Set 7 | rochester
# Processing Record 4 of Set 7 | sitia
# Processing Record 5 of Set 7 | vlcnov
# Processing Record 6 of Set 7 | winneba
# Processing Record 7 of Set 7 | kloulklubed
# Processing Record 8 of Set 7 | walvis bay
# Processing Record 9 of Set 7 | ust-nera
# Processing Record 10 of Set 7 | yaan
# Processing Record 11 of Set 7 | graaff-reinet
# Processing Record 12 of Set 7 | ginir
# Processing Record 13 of Set 7 | vega de alatorre
# Processing Record 14 of Set 7 | saint-augustin
# Processing Record 15 of Set 7 | biltine
# Processing Record 16 of Set 7 | whitley bay
# Processing Record 17 of Set 7 | zheleznodorozhnyy
# Processing Record 18 of Set 7 | luang prabang
# Processing Record 19 of Set 7 | skjervoy
# Processing Record 20 of Set 7 | krasnoselkup
# Processing Record 21 of Set 7 | pemangkat
# Processing Record 22 of Set 7 | dalvik
# Processing Record 23 of Set 7 | piura
# Processing Record 24 of Set 7 | grants pass
# Processing Record 25 of Set 7 | roebourne
# Processing Record 26 of Set 7 | matadi
# Processing Record 27 of Set 7 | esmeralda
# Processing Record 28 of Set 7 | buala
# Processing Record 29 of Set 7 | sechura
# Processing Record 30 of Set 7 | bealanana
# Processing Record 31 of Set 7 | puerto escondido
# Processing Record 32 of Set 7 | tura
# Processing Record 33 of Set 7 | isangel
# Processing Record 34 of Set 7 | san rafael del sur
# Processing Record 35 of Set 7 | kaeo
# Processing Record 36 of Set 7 | tazovskiy
# Processing Record 37 of Set 7 | fostoria
# Processing Record 38 of Set 7 | arraial do cabo
# Processing Record 39 of Set 7 | bom jesus
# Processing Record 40 of Set 7 | te anau
# Processing Record 41 of Set 7 | biu
# Processing Record 42 of Set 7 | los zacatones
# Processing Record 43 of Set 7 | ulladulla
# Processing Record 44 of Set 7 | berlevag
# Processing Record 45 of Set 7 | ribeira grande
# Processing Record 46 of Set 7 | parainen
# Processing Record 47 of Set 7 | jalu
# Processing Record 48 of Set 7 | turbat
# Processing Record 49 of Set 7 | maxixe
# Processing Record 50 of Set 7 | stephenville
# Processing Record 1 of Set 8 | isoka
# Processing Record 2 of Set 8 | vanimo
# Processing Record 3 of Set 8 | luau
# Processing Record 4 of Set 8 | ahipara
# Processing Record 5 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 8 | bekhtery
# Processing Record 7 of Set 8 | vila
# Processing Record 8 of Set 8 | kismayo
# Processing Record 9 of Set 8 | dongsheng
# Processing Record 10 of Set 8 | guerrero negro
# Processing Record 11 of Set 8 | portland
# Processing Record 12 of Set 8 | jacareacanga
# Processing Record 13 of Set 8 | aguimes
# Processing Record 14 of Set 8 | ukiah
# Processing Record 15 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 8 | lamu
# Processing Record 17 of Set 8 | kralendijk
# Processing Record 18 of Set 8 | qinzhou
# Processing Record 19 of Set 8 | mecca
# Processing Record 20 of Set 8 | aldan
# Processing Record 21 of Set 8 | mahajanga
# Processing Record 22 of Set 8 | rocha
# Processing Record 23 of Set 8 | awbari
# Processing Record 24 of Set 8 | kilimatinde
# Processing Record 25 of Set 8 | smidovich
# Processing Record 26 of Set 8 | kontagora
# Processing Record 27 of Set 8 | raipur
# Processing Record 28 of Set 8 | anadyr
# Processing Record 29 of Set 8 | missoula
# Processing Record 30 of Set 8 | bud
# Processing Record 31 of Set 8 | la ronge
# Processing Record 32 of Set 8 | batagay-alyta
# Processing Record 33 of Set 8 | strezhevoy
# Processing Record 34 of Set 8 | ostrovnoy
# Processing Record 35 of Set 8 | nha trang
# Processing Record 36 of Set 8 | suntar
# Processing Record 37 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 8 | okato
# Processing Record 39 of Set 8 | husavik
# Processing Record 40 of Set 8 | poum
# Processing Record 41 of Set 8 | east london
# Processing Record 42 of Set 8 | seoul
# Processing Record 43 of Set 8 | taoudenni
# Processing Record 44 of Set 8 | salina cruz
# Processing Record 45 of Set 8 | sangar
# Processing Record 46 of Set 8 | gigante
# Processing Record 47 of Set 8 | huicheng
# Processing Record 48 of Set 8 | severo-kurilsk
# Processing Record 49 of Set 8 | sal rei
# Processing Record 50 of Set 8 | swan hill
# Processing Record 1 of Set 9 | bundaberg
# Processing Record 2 of Set 9 | ondjiva
# Processing Record 3 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 9 | hamilton
# Processing Record 5 of Set 9 | ginda
# Processing Record 6 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 9 | fort nelson
# Processing Record 8 of Set 9 | mayumba
# Processing Record 9 of Set 9 | katherine
# Processing Record 10 of Set 9 | dudinka
# Processing Record 11 of Set 9 | talnakh
# Processing Record 12 of Set 9 | vetlanda
# Processing Record 13 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 9 | kahului
# Processing Record 16 of Set 9 | mishan
# Processing Record 17 of Set 9 | glenwood springs
# Processing Record 18 of Set 9 | tupik
# Processing Record 19 of Set 9 | bitung
# Processing Record 20 of Set 9 | si sa ket
# Processing Record 21 of Set 9 | jyvaskyla
# Processing Record 22 of Set 9 | lebanon
# Processing Record 23 of Set 9 | galesong
# Processing Record 24 of Set 9 | kaseda
# Processing Record 25 of Set 9 | hutchinson
# Processing Record 26 of Set 9 | hambantota
# Processing Record 27 of Set 9 | camposampiero
# Processing Record 28 of Set 9 | severodvinsk
# Processing Record 29 of Set 9 | saint-paul
# Processing Record 30 of Set 9 | santa isabel
# Processing Record 31 of Set 9 | broken hill
# Processing Record 32 of Set 9 | batagay
# Processing Record 33 of Set 9 | floro
# Processing Record 34 of Set 9 | bardiyah
# Processing Record 35 of Set 9 | saint anthony
# Processing Record 36 of Set 9 | melita
# Processing Record 37 of Set 9 | hovd
# Processing Record 38 of Set 9 | litovko
# Processing Record 39 of Set 9 | tumbagaan
# Processing Record 40 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 41 of Set 9 | rundu
# Processing Record 42 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 9 | port-gentil
# Processing Record 44 of Set 9 | axim
# Processing Record 45 of Set 9 | zhangjiakou
# Processing Record 46 of Set 9 | beringovskiy
# Processing Record 47 of Set 9 | taguatinga
# Processing Record 48 of Set 9 | jos
# Processing Record 49 of Set 9 | rio gallegos
# Processing Record 50 of Set 9 | buluang
# Processing Record 1 of Set 10 | mirabad
# Processing Record 2 of Set 10 | waipawa
# Processing Record 3 of Set 10 | sakaiminato
# Processing Record 4 of Set 10 | shimoda
# Processing Record 5 of Set 10 | mogadishu
# Processing Record 6 of Set 10 | celestun
# Processing Record 7 of Set 10 | pacific grove
# Processing Record 8 of Set 10 | odry
# Processing Record 9 of Set 10 | zelion
# City not found. Skipping...
# Processing Record 10 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 10 | barstow
# Processing Record 12 of Set 10 | krasnokamensk
# Processing Record 13 of Set 10 | san pedro
# Processing Record 14 of Set 10 | le vauclin
# Processing Record 15 of Set 10 | chimore
# Processing Record 16 of Set 10 | poso
# Processing Record 17 of Set 10 | liuhe
# Processing Record 18 of Set 10 | sarangani
# Processing Record 19 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 20 of Set 10 | kamenka
# Processing Record 21 of Set 10 | joshimath
# Processing Record 22 of Set 10 | matto
# City not found. Skipping...
# Processing Record 23 of Set 10 | hit
# Processing Record 24 of Set 10 | mirnyy
# Processing Record 25 of Set 10 | hudson bay
# Processing Record 26 of Set 10 | narsaq
# Processing Record 27 of Set 10 | timon
# Processing Record 28 of Set 10 | am timan
# Processing Record 29 of Set 10 | crawfordsville
# Processing Record 30 of Set 10 | hwange
# Processing Record 31 of Set 10 | kaitangata
# Processing Record 32 of Set 10 | cap malheureux
# Processing Record 33 of Set 10 | alikalia
# Processing Record 34 of Set 10 | borgarnes
# Processing Record 35 of Set 10 | prilep
# Processing Record 36 of Set 10 | dali
# Processing Record 37 of Set 10 | camacha
# Processing Record 38 of Set 10 | olafsvik
# Processing Record 39 of Set 10 | eureka
# Processing Record 40 of Set 10 | kenai
# Processing Record 41 of Set 10 | khani
# Processing Record 42 of Set 10 | san rafael
# Processing Record 43 of Set 10 | apomu
# Processing Record 44 of Set 10 | eskisehir
# Processing Record 45 of Set 10 | koungou
# Processing Record 46 of Set 10 | cortez
# Processing Record 47 of Set 10 | tagusao
# Processing Record 48 of Set 10 | merauke
# Processing Record 49 of Set 10 | grand gaube
# Processing Record 50 of Set 10 | novikovo
# Processing Record 1 of Set 11 | kharp
# Processing Record 2 of Set 11 | antsohihy
# Processing Record 3 of Set 11 | bumba
# Processing Record 4 of Set 11 | kuching
# Processing Record 5 of Set 11 | kalmar
# Processing Record 6 of Set 11 | ballina
# Processing Record 7 of Set 11 | giurgeni
# Processing Record 8 of Set 11 | leningradskiy
# Processing Record 9 of Set 11 | ayotzintepec
# Processing Record 10 of Set 11 | kampong thum
# Processing Record 11 of Set 11 | huilong
# Processing Record 12 of Set 11 | areka
# Processing Record 13 of Set 11 | inuvik
# Processing Record 14 of Set 11 | santa marta
# Processing Record 15 of Set 11 | camiri
# Processing Record 16 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 11 | denpasar
# Processing Record 18 of Set 11 | scarborough
# Processing Record 19 of Set 11 | half moon bay
# Processing Record 20 of Set 11 | alice springs
# Processing Record 21 of Set 11 | gambela
# Processing Record 22 of Set 11 | ituacu
# Processing Record 23 of Set 11 | luanda
# Processing Record 24 of Set 11 | salinas
# Processing Record 25 of Set 11 | iralaya
# Processing Record 26 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 27 of Set 11 | jever
# Processing Record 28 of Set 11 | bagamoyo
# Processing Record 29 of Set 11 | katsuura
# Processing Record 30 of Set 11 | yagodnoye
# Processing Record 31 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 11 | conceicao da barra
# Processing Record 33 of Set 11 | lubbeek
# Processing Record 34 of Set 11 | clyde river
# Processing Record 35 of Set 11 | arlit
# Processing Record 36 of Set 11 | prince george
# Processing Record 37 of Set 11 | grand-santi
# Processing Record 38 of Set 11 | yerbogachen
# Processing Record 39 of Set 11 | ferrol
# Processing Record 40 of Set 11 | mitu
# Processing Record 41 of Set 11 | kanniyakumari
# Processing Record 42 of Set 11 | port hedland
# Processing Record 43 of Set 11 | altamont
# Processing Record 44 of Set 11 | dandong
# Processing Record 45 of Set 11 | date
# Processing Record 46 of Set 11 | ishigaki
# Processing Record 47 of Set 11 | touzim
# Processing Record 48 of Set 11 | necochea
# Processing Record 49 of Set 11 | wattegama
# Processing Record 50 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 2 of Set 12 | rauma
# Processing Record 3 of Set 12 | san vicente
# Processing Record 4 of Set 12 | takoradi
# Processing Record 5 of Set 12 | griffith
# Processing Record 6 of Set 12 | port hardy
# Processing Record 7 of Set 12 | kurumkan
# Processing Record 8 of Set 12 | qasigiannguit
# Processing Record 9 of Set 12 | ossora
# Processing Record 10 of Set 12 | samarai
# Processing Record 11 of Set 12 | san ciro de acosta
# Processing Record 12 of Set 12 | enterprise
# Processing Record 13 of Set 12 | port augusta
# Processing Record 14 of Set 12 | poya
# Processing Record 15 of Set 12 | yeniseysk
# Processing Record 16 of Set 12 | grindavik
# Processing Record 17 of Set 12 | berezovka
# Processing Record 18 of Set 12 | nisia floresta
# Processing Record 19 of Set 12 | ancud
# Processing Record 20 of Set 12 | demirci
# Processing Record 21 of Set 12 | la asuncion
# Processing Record 22 of Set 12 | point fortin
# Processing Record 23 of Set 12 | kitgum
# Processing Record 24 of Set 12 | ketchikan
# Processing Record 25 of Set 12 | itarema
# Processing Record 26 of Set 12 | verkhnyaya inta
# Processing Record 27 of Set 12 | nantucket
# Processing Record 28 of Set 12 | punta alta
# Processing Record 29 of Set 12 | karasjok
# Processing Record 30 of Set 12 | novobirilyussy
# Processing Record 31 of Set 12 | punta de bombon
# Processing Record 32 of Set 12 | mae sot
# Processing Record 33 of Set 12 | aksarka
# Processing Record 34 of Set 12 | lyuban
# Processing Record 35 of Set 12 | alcaniz
# Processing Record 36 of Set 12 | lourdes
# Processing Record 37 of Set 12 | malmyzh
# Processing Record 38 of Set 12 | biak
# Processing Record 39 of Set 12 | nakhon si thammarat
# Processing Record 40 of Set 12 | fairbanks
# Processing Record 41 of Set 12 | lubu
# Processing Record 42 of Set 12 | champerico
# Processing Record 43 of Set 12 | haicheng
# Processing Record 44 of Set 12 | raga
# Processing Record 45 of Set 12 | gamba
# Processing Record 46 of Set 12 | kysyl-syr
# Processing Record 47 of Set 12 | camargo
# Processing Record 48 of Set 12 | waddan
# Processing Record 49 of Set 12 | vincennes
# Processing Record 50 of Set 12 | moerai
# Processing Record 1 of Set 13 | aanekoski
# Processing Record 2 of Set 13 | bandarbeyla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 50.8122, 'lat': 9.4942},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 93.16,
#   'feels_like': 102.9,
#   'temp_min': 93.16,
#   'temp_max': 93.16,
#   'pressure': 1008,
#   'humidity': 53,
#   'sea_level': 1008,
#   'grnd_level': 1006},
#  'visibility': 10000,
#  'wind': {'speed': 16.24, 'deg': 155, 'gust': 13.51},
#  'clouds': {'all': 88},
#  'dt': 1651566767,
#  'sys': {'country': 'SO', 'sunrise': 1651544362, 'sunset': 1651589268},
#  'timezone': 10800,
#  'id': 64814,
#  'name': 'Bandarbeyla',
#  'cod': 200}

# %%
#convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Nikolskoye  59.7035   30.7861     49.91        40          10
# 1                Ushuaia -54.8000  -68.3000     38.86        75          40
# 2            Tuktoyaktuk  69.4541 -133.0374     33.10        94         100
# 3              Busselton -33.6500  115.3333     63.82        58          99
# 4               Tateyama  34.9833  139.8667     59.67        66          12
# 5                 Albany  42.6001  -73.9662     48.61        91         100
# 6                  Tiksi  71.6872  128.8694     20.52        79         100
# 7                   Lata  40.1629   -8.3327     62.08        67           7
# 8                 Moyale   3.5167   39.0584     72.95        73         100
# 9  Los Llanos De Aridane  28.6585  -17.9182     62.35        80          75
#
#    Wind Speed Country                 Date
# 0       14.72      RU  2022-05-03 08:15:12
# 1       19.57      AR  2022-05-03 08:11:24
# 2        3.53      CA  2022-05-03 08:15:12
# 3       14.09      AU  2022-05-03 08:14:45
# 4       12.24      JP  2022-05-03 08:15:13
# 5        0.96      US  2022-05-03 08:10:54
# 6        2.19      RU  2022-05-03 08:15:14
# 7       10.27      PT  2022-05-03 08:15:14
# 8       10.96      KE  2022-05-03 08:14:31
# 9       14.97      ES  2022-05-03 08:15:15

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0     Nikolskoye      RU  2022-05-03 08:15:12  59.7035   30.7861     49.91
# 1        Ushuaia      AR  2022-05-03 08:11:24 -54.8000  -68.3000     38.86
# 2    Tuktoyaktuk      CA  2022-05-03 08:15:12  69.4541 -133.0374     33.10
# 3      Busselton      AU  2022-05-03 08:14:45 -33.6500  115.3333     63.82
# 4       Tateyama      JP  2022-05-03 08:15:13  34.9833  139.8667     59.67
# ..           ...     ...                  ...      ...       ...       ...
# 556       Waddan      LY  2022-05-03 08:31:45  29.1614   16.1390     71.73
# 557    Vincennes      FR  2022-05-03 08:31:45  48.8500    2.4333     60.30
# 558       Moerai      PF  2022-05-03 08:31:46 -22.4333 -151.3333     77.95
# 559    Aanekoski      FI  2022-05-03 08:32:46  62.6946   25.8180     33.87
# 560  Bandarbeyla      SO  2022-05-03 08:32:47   9.4942   50.8122     93.16
#
#      Humidity  Cloudiness  Wind Speed
# 0          40          10       14.72
# 1          75          40       19.57
# 2          94         100        3.53
# 3          58          99       14.09
# 4          66          12       12.24
# ..        ...         ...         ...
# 556        32           0        0.36
# 557        66           0       13.80
# 558        84          99       16.33
# 559        71         100       15.59
# 560        53          88       16.24
#
# [561 rows x 9 columns]

# %%
#create the output file (CSV).
output_data_file = "C:/Users/Elissa/World_Weather_Analysis/weather_data/cities.csv"
#export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
#import time module
import time

#build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

#incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#save the figure.
plt.savefig("weather_data/Fig1.png")
plt.show()

# %%
#build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

#incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
#save the figure.
plt.savefig("weather_data/Fig2.png")
plt.show()

# %%
#build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

#incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
#save the figure.
plt.savefig("weather_data/Fig3.png")
plt.show()

# %%
#build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

#incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
#save the figure.
plt.savefig("weather_data/Fig4.png")
plt.show()

# %%
#import linregress
from scipy.stats import linregress

#create function to create perform linear regression on weather data & plot regression line and equation with data
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    #run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    #calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    #equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    #create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    #annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()
    
    #print linregress
    print(linregress(x_values, y_values))

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                        Bluff
# Country                        NZ
# Date          2022-05-03 08:14:34
# Lat                         -46.6
# Lng                      168.3333
# Max Temp                     55.8
# Humidity                       78
# Cloudiness                     56
# Wind Speed                   5.64
# Name: 13, dtype: object

# %%
#create northern and southern hemisphere df
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
#preform linregress on Max Temp on hemisphere
#linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
#call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Maximum Temperature',
                       'Max Temp',(10,10))
# Out:
# LinregressResult(slope=-0.8973923955989492, intercept=93.31234659678287, rvalue=-0.8735671006278706, pvalue=3.779913808813281e-122, stderr=0.025514389295717966, intercept_stderr=1.1193635547096892)

# %%
#linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
#call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature',
                       'Max Temp',(-50,90))
# Out:
# LinregressResult(slope=0.6484782848437308, intercept=84.65858098896612, rvalue=0.6951166130312789, pvalue=1.3834077576865625e-26, stderr=0.05098957455870171, intercept_stderr=1.3052908400874244)

# %%
#linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
#call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity',
                       '% Humidity',(45,0))
# Out:
# LinregressResult(slope=0.15570877070550987, intercept=61.73849238679215, rvalue=0.14148408204737575, pvalue=0.005357275522815118, stderr=0.05559669665421255, intercept_stderr=2.439130142433787)

# %%
#linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity',
                       '% Humidity',(-55,25))
# Out:
# LinregressResult(slope=0.10622367887903175, intercept=75.2483888616048, rvalue=0.08193082123632782, pvalue=0.281083352864329, stderr=0.09824001701162789, intercept_stderr=2.51486299787977)

# %%
#linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
#call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Cloudiness Hemisphere \n for % Humidity',
                       '% Humidity',(23,52))
# Out:
# LinregressResult(slope=0.1431669120767717, intercept=58.88280076825238, rvalue=0.07812068823878575, pvalue=0.12547490355168975, stderr=0.09323558698526332, intercept_stderr=4.090418032885627)

# %%
#linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
#call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness',
                       '% Cloudiness',(-55,55))
# Out:
# LinregressResult(slope=0.5891857901672013, intercept=61.539677474741474, rvalue=0.1989449478506744, pvalue=0.008306018038735732, stderr=0.2206617715800406, intercept_stderr=5.648758431378924)

# %%
#linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
#call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed',\
                       'Wind Speed',(0,23))
# Out:
# LinregressResult(slope=0.036909154255889816, intercept=7.498486601399266, rvalue=0.13708256462060023, pvalue=0.006991375812787191, stderr=0.013610274454759255, intercept_stderr=0.5971079698470633)

# %%
#linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
#call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed',\
                       'Wind Speed',(-55,18))
# Out:
# LinregressResult(slope=-0.055993710038348486, intercept=6.69212955369021, rvalue=-0.1439364227303032, pvalue=0.05738563884702149, stderr=0.02926843097518409, intercept_stderr=0.7492475704353391)
