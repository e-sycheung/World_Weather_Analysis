# %%
#import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time
from config import weather_api_key

# %%
#create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#create a list for holding the cities.
cities = []
#identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #if the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
#create empty list to hold the weather data
city_data = []
#print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("-------------------------------")

#create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -------------------------------

# %%
#starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#loop through all the cities in the list.
for i, city in enumerate(cities):

    #group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    #create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    #log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    #run an API request for each of the cities.
    try:
        #parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    #if an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | alizai
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | shizunai
# Processing Record 6 of Set 1 | sola
# Processing Record 7 of Set 1 | chuy
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | hasaki
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | bardiyah
# Processing Record 16 of Set 1 | ossora
# Processing Record 17 of Set 1 | eureka
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | avera
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | sijunjung
# Processing Record 22 of Set 1 | vestmannaeyjar
# Processing Record 23 of Set 1 | gemena
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | auki
# Processing Record 26 of Set 1 | ergolding
# Processing Record 27 of Set 1 | yerbogachen
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | sao felix do xingu
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | cartagena
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 1 | pisco
# Processing Record 36 of Set 1 | svetlogorsk
# Processing Record 37 of Set 1 | klaksvik
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | yeppoon
# Processing Record 40 of Set 1 | aki
# Processing Record 41 of Set 1 | southbridge
# Processing Record 42 of Set 1 | kloulklubed
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | fairmont
# Processing Record 46 of Set 1 | najran
# Processing Record 47 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | maumere
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | aswan
# Processing Record 3 of Set 2 | luwuk
# Processing Record 4 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 2 | dakar
# Processing Record 6 of Set 2 | brae
# Processing Record 7 of Set 2 | yenagoa
# Processing Record 8 of Set 2 | nanzhou
# Processing Record 9 of Set 2 | taksimo
# Processing Record 10 of Set 2 | yelatma
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | dumas
# Processing Record 13 of Set 2 | anadyr
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | altay
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | mahibadhoo
# Processing Record 18 of Set 2 | qujing
# Processing Record 19 of Set 2 | roblin
# Processing Record 20 of Set 2 | cidreira
# Processing Record 21 of Set 2 | poronaysk
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | mount isa
# Processing Record 24 of Set 2 | khorixas
# Processing Record 25 of Set 2 | la palma
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | ozinki
# Processing Record 31 of Set 2 | marasesti
# Processing Record 32 of Set 2 | tuatapere
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | hami
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | nanortalik
# Processing Record 37 of Set 2 | caravelas
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | dawei
# Processing Record 41 of Set 2 | kibala
# Processing Record 42 of Set 2 | penzance
# Processing Record 43 of Set 2 | tabuk
# Processing Record 44 of Set 2 | namatanai
# Processing Record 45 of Set 2 | yumen
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | port blair
# Processing Record 48 of Set 2 | deputatskiy
# Processing Record 49 of Set 2 | tucurui
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | vallenar
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | biak
# Processing Record 4 of Set 3 | ahuimanu
# Processing Record 5 of Set 3 | geraldton
# Processing Record 6 of Set 3 | klokkarvik
# City not found. Skipping...
# Processing Record 7 of Set 3 | mlonggo
# Processing Record 8 of Set 3 | horki
# Processing Record 9 of Set 3 | pandamatenga
# Processing Record 10 of Set 3 | beringovskiy
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | khandyga
# Processing Record 13 of Set 3 | lorengau
# Processing Record 14 of Set 3 | sindand
# City not found. Skipping...
# Processing Record 15 of Set 3 | lavrentiya
# Processing Record 16 of Set 3 | hofn
# Processing Record 17 of Set 3 | tempio pausania
# Processing Record 18 of Set 3 | gorontalo
# Processing Record 19 of Set 3 | perevoz
# Processing Record 20 of Set 3 | grindavik
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | manggar
# Processing Record 23 of Set 3 | makakilo city
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | kilembe
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | camopi
# Processing Record 28 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 3 | sinnamary
# Processing Record 30 of Set 3 | mackay
# Processing Record 31 of Set 3 | dukat
# Processing Record 32 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | myitkyina
# Processing Record 35 of Set 3 | mataura
# Processing Record 36 of Set 3 | leningradskiy
# Processing Record 37 of Set 3 | adrar
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | kota kinabalu
# Processing Record 40 of Set 3 | atuona
# Processing Record 41 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 42 of Set 3 | oneida
# Processing Record 43 of Set 3 | takoradi
# Processing Record 44 of Set 3 | cape town
# Processing Record 45 of Set 3 | horta
# Processing Record 46 of Set 3 | cuenca
# Processing Record 47 of Set 3 | praia da vitoria
# Processing Record 48 of Set 3 | pangnirtung
# Processing Record 49 of Set 3 | sao jose da coroa grande
# Processing Record 50 of Set 3 | kalabugao
# City not found. Skipping...
# Processing Record 1 of Set 4 | iqaluit
# Processing Record 2 of Set 4 | kingsport
# Processing Record 3 of Set 4 | abu samrah
# Processing Record 4 of Set 4 | zhigansk
# Processing Record 5 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 4 | kentau
# Processing Record 7 of Set 4 | bathsheba
# Processing Record 8 of Set 4 | skjervoy
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | beaverton
# Processing Record 11 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | soe
# Processing Record 13 of Set 4 | san rafael
# Processing Record 14 of Set 4 | hualmay
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | san cristobal
# Processing Record 17 of Set 4 | narsaq
# Processing Record 18 of Set 4 | alakurtti
# Processing Record 19 of Set 4 | pitimbu
# Processing Record 20 of Set 4 | el retorno
# Processing Record 21 of Set 4 | lyuban
# Processing Record 22 of Set 4 | kaitangata
# Processing Record 23 of Set 4 | ban nahin
# Processing Record 24 of Set 4 | castro
# Processing Record 25 of Set 4 | saskylakh
# Processing Record 26 of Set 4 | flinders
# Processing Record 27 of Set 4 | morro bay
# Processing Record 28 of Set 4 | ibra
# Processing Record 29 of Set 4 | hilo
# Processing Record 30 of Set 4 | oinoussai
# City not found. Skipping...
# Processing Record 31 of Set 4 | kruisfontein
# Processing Record 32 of Set 4 | bredasdorp
# Processing Record 33 of Set 4 | san luis
# Processing Record 34 of Set 4 | ghanzi
# Processing Record 35 of Set 4 | avarua
# Processing Record 36 of Set 4 | macau
# Processing Record 37 of Set 4 | luderitz
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | shache
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | dzaoudzi
# Processing Record 42 of Set 4 | batagay-alyta
# Processing Record 43 of Set 4 | krasnoselkup
# Processing Record 44 of Set 4 | ladushkin
# Processing Record 45 of Set 4 | acarau
# Processing Record 46 of Set 4 | praia
# Processing Record 47 of Set 4 | marsaxlokk
# Processing Record 48 of Set 4 | knysna
# Processing Record 49 of Set 4 | rognan
# Processing Record 50 of Set 4 | omboue
# Processing Record 1 of Set 5 | mount gambier
# Processing Record 2 of Set 5 | oussouye
# Processing Record 3 of Set 5 | irklievskaya
# City not found. Skipping...
# Processing Record 4 of Set 5 | ryotsu
# Processing Record 5 of Set 5 | lebu
# Processing Record 6 of Set 5 | siva
# Processing Record 7 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 5 | balta
# Processing Record 9 of Set 5 | arraial do cabo
# Processing Record 10 of Set 5 | haines junction
# Processing Record 11 of Set 5 | ingelheim
# City not found. Skipping...
# Processing Record 12 of Set 5 | tuktoyaktuk
# Processing Record 13 of Set 5 | nouadhibou
# Processing Record 14 of Set 5 | torbay
# Processing Record 15 of Set 5 | tazovskiy
# Processing Record 16 of Set 5 | santa maria
# Processing Record 17 of Set 5 | teahupoo
# Processing Record 18 of Set 5 | korla
# Processing Record 19 of Set 5 | nikki
# Processing Record 20 of Set 5 | eirunepe
# Processing Record 21 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | qingdao
# Processing Record 24 of Set 5 | kapaa
# Processing Record 25 of Set 5 | dikson
# Processing Record 26 of Set 5 | alyangula
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | aksha
# Processing Record 29 of Set 5 | marawi
# Processing Record 30 of Set 5 | kaeo
# Processing Record 31 of Set 5 | kurush
# Processing Record 32 of Set 5 | melfort
# Processing Record 33 of Set 5 | quatre cocos
# Processing Record 34 of Set 5 | itaituba
# Processing Record 35 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 5 | carmen
# Processing Record 37 of Set 5 | kaele
# Processing Record 38 of Set 5 | sitka
# Processing Record 39 of Set 5 | batemans bay
# Processing Record 40 of Set 5 | labuhan
# Processing Record 41 of Set 5 | les cayes
# Processing Record 42 of Set 5 | kualakapuas
# Processing Record 43 of Set 5 | genhe
# Processing Record 44 of Set 5 | vostok
# Processing Record 45 of Set 5 | kardla
# Processing Record 46 of Set 5 | christchurch
# Processing Record 47 of Set 5 | shimoda
# Processing Record 48 of Set 5 | bollnas
# Processing Record 49 of Set 5 | mogadouro
# Processing Record 50 of Set 5 | meulaboh
# Processing Record 1 of Set 6 | del rio
# Processing Record 2 of Set 6 | yar-sale
# Processing Record 3 of Set 6 | mandalgovi
# Processing Record 4 of Set 6 | tukrah
# Processing Record 5 of Set 6 | turan
# Processing Record 6 of Set 6 | chapais
# Processing Record 7 of Set 6 | turayf
# Processing Record 8 of Set 6 | nuuk
# Processing Record 9 of Set 6 | mounana
# Processing Record 10 of Set 6 | west melbourne
# Processing Record 11 of Set 6 | harbour breton
# Processing Record 12 of Set 6 | kuminskiy
# Processing Record 13 of Set 6 | borgarnes
# Processing Record 14 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 6 | rocha
# Processing Record 16 of Set 6 | bubaque
# Processing Record 17 of Set 6 | edmundston
# Processing Record 18 of Set 6 | matara
# Processing Record 19 of Set 6 | san pedro
# Processing Record 20 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 6 | khatanga
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | port hardy
# Processing Record 24 of Set 6 | espanola
# Processing Record 25 of Set 6 | alice springs
# Processing Record 26 of Set 6 | bath
# Processing Record 27 of Set 6 | abilene
# Processing Record 28 of Set 6 | verkhnevilyuysk
# Processing Record 29 of Set 6 | tilichiki
# Processing Record 30 of Set 6 | dwarka
# Processing Record 31 of Set 6 | puerto escondido
# Processing Record 32 of Set 6 | porto velho
# Processing Record 33 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 6 | ust-koksa
# Processing Record 35 of Set 6 | wangqing
# Processing Record 36 of Set 6 | bonavista
# Processing Record 37 of Set 6 | abu dhabi
# Processing Record 38 of Set 6 | fort nelson
# Processing Record 39 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 6 | ust-nera
# Processing Record 41 of Set 6 | constitucion
# Processing Record 42 of Set 6 | virginia beach
# Processing Record 43 of Set 6 | sechura
# Processing Record 44 of Set 6 | beyneu
# Processing Record 45 of Set 6 | tateyama
# Processing Record 46 of Set 6 | akyab
# Processing Record 47 of Set 6 | sur
# Processing Record 48 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 6 | richards bay
# Processing Record 50 of Set 6 | orange cove
# Processing Record 1 of Set 7 | antalaha
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | san vicente
# Processing Record 4 of Set 7 | mayo
# Processing Record 5 of Set 7 | bjornevatn
# Processing Record 6 of Set 7 | papasquiaro
# City not found. Skipping...
# Processing Record 7 of Set 7 | chokurdakh
# Processing Record 8 of Set 7 | umea
# Processing Record 9 of Set 7 | ilulissat
# Processing Record 10 of Set 7 | belaya gora
# Processing Record 11 of Set 7 | kuusamo
# Processing Record 12 of Set 7 | chumikan
# Processing Record 13 of Set 7 | mwinilunga
# Processing Record 14 of Set 7 | kamenka
# Processing Record 15 of Set 7 | tual
# Processing Record 16 of Set 7 | dire
# Processing Record 17 of Set 7 | cocorit
# Processing Record 18 of Set 7 | sistranda
# Processing Record 19 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 7 | chipoka
# Processing Record 21 of Set 7 | tangua
# Processing Record 22 of Set 7 | araouane
# Processing Record 23 of Set 7 | huejuquilla el alto
# Processing Record 24 of Set 7 | touros
# Processing Record 25 of Set 7 | puyo
# Processing Record 26 of Set 7 | manavalakurichi
# Processing Record 27 of Set 7 | college
# Processing Record 28 of Set 7 | baracoa
# Processing Record 29 of Set 7 | celestun
# Processing Record 30 of Set 7 | acandi
# Processing Record 31 of Set 7 | floro
# Processing Record 32 of Set 7 | tari
# Processing Record 33 of Set 7 | grand gaube
# Processing Record 34 of Set 7 | xichang
# Processing Record 35 of Set 7 | olinda
# Processing Record 36 of Set 7 | miles city
# Processing Record 37 of Set 7 | itupiranga
# Processing Record 38 of Set 7 | garmsar
# Processing Record 39 of Set 7 | hastings
# Processing Record 40 of Set 7 | bilibino
# Processing Record 41 of Set 7 | alofi
# Processing Record 42 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 7 | mehamn
# Processing Record 44 of Set 7 | malkara
# Processing Record 45 of Set 7 | cayenne
# Processing Record 46 of Set 7 | leopold
# Processing Record 47 of Set 7 | kargil
# Processing Record 48 of Set 7 | kargapolye
# City not found. Skipping...
# Processing Record 49 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 7 | uinskoye
# Processing Record 1 of Set 8 | saint-joseph
# Processing Record 2 of Set 8 | sirjan
# Processing Record 3 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 | severo-kurilsk
# Processing Record 6 of Set 8 | devils lake
# Processing Record 7 of Set 8 | bentiu
# Processing Record 8 of Set 8 | mar del plata
# Processing Record 9 of Set 8 | namibe
# Processing Record 10 of Set 8 | omsukchan
# Processing Record 11 of Set 8 | banda aceh
# Processing Record 12 of Set 8 | coquimbo
# Processing Record 13 of Set 8 | thinadhoo
# Processing Record 14 of Set 8 | yabrud
# Processing Record 15 of Set 8 | klyuchi
# Processing Record 16 of Set 8 | awbari
# Processing Record 17 of Set 8 | broome
# Processing Record 18 of Set 8 | hovd
# Processing Record 19 of Set 8 | wellin
# Processing Record 20 of Set 8 | walvis bay
# Processing Record 21 of Set 8 | udaipura
# Processing Record 22 of Set 8 | bereda
# Processing Record 23 of Set 8 | sembe
# Processing Record 24 of Set 8 | point pleasant
# Processing Record 25 of Set 8 | kenora
# Processing Record 26 of Set 8 | kerrville
# Processing Record 27 of Set 8 | thongwa
# Processing Record 28 of Set 8 | sorland
# Processing Record 29 of Set 8 | belen
# Processing Record 30 of Set 8 | kozhva
# Processing Record 31 of Set 8 | nador
# Processing Record 32 of Set 8 | minnedosa
# Processing Record 33 of Set 8 | fairbanks
# Processing Record 34 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 8 | palmas de monte alto
# Processing Record 36 of Set 8 | ballina
# Processing Record 37 of Set 8 | santiago de chuco
# Processing Record 38 of Set 8 | manoel urbano
# Processing Record 39 of Set 8 | waddan
# Processing Record 40 of Set 8 | boca do acre
# Processing Record 41 of Set 8 | revelstoke
# Processing Record 42 of Set 8 | east london
# Processing Record 43 of Set 8 | pevek
# Processing Record 44 of Set 8 | kalabo
# Processing Record 45 of Set 8 | clyde river
# Processing Record 46 of Set 8 | johi
# Processing Record 47 of Set 8 | poyarkovo
# Processing Record 48 of Set 8 | sabang
# Processing Record 49 of Set 8 | anloga
# Processing Record 50 of Set 8 | luebo
# Processing Record 1 of Set 9 | fare
# Processing Record 2 of Set 9 | cochabamba
# Processing Record 3 of Set 9 | aginskoye
# Processing Record 4 of Set 9 | yuxia
# Processing Record 5 of Set 9 | riyadh
# Processing Record 6 of Set 9 | northam
# Processing Record 7 of Set 9 | bandarbeyla
# Processing Record 8 of Set 9 | katsuura
# Processing Record 9 of Set 9 | abancay
# Processing Record 10 of Set 9 | roald
# Processing Record 11 of Set 9 | hervey bay
# Processing Record 12 of Set 9 | wawa
# Processing Record 13 of Set 9 | isangel
# Processing Record 14 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 9 | saint anthony
# Processing Record 16 of Set 9 | ambilobe
# Processing Record 17 of Set 9 | fortuna
# Processing Record 18 of Set 9 | krasnokholm
# Processing Record 19 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 9 | dunedin
# Processing Record 21 of Set 9 | chapleau
# Processing Record 22 of Set 9 | yurgamysh
# Processing Record 23 of Set 9 | igrim
# Processing Record 24 of Set 9 | uyovu
# Processing Record 25 of Set 9 | athabasca
# Processing Record 26 of Set 9 | shieli
# Processing Record 27 of Set 9 | hutchinson
# Processing Record 28 of Set 9 | mahebourg
# Processing Record 29 of Set 9 | aklavik
# Processing Record 30 of Set 9 | ponta delgada
# Processing Record 31 of Set 9 | belyy yar
# Processing Record 32 of Set 9 | port lincoln
# Processing Record 33 of Set 9 | palasa
# Processing Record 34 of Set 9 | neulengbach
# Processing Record 35 of Set 9 | saldanha
# Processing Record 36 of Set 9 | koumac
# Processing Record 37 of Set 9 | kot radha kishan
# Processing Record 38 of Set 9 | springhill
# Processing Record 39 of Set 9 | dingle
# Processing Record 40 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 9 | chutove
# Processing Record 42 of Set 9 | ivdel
# Processing Record 43 of Set 9 | zaysan
# Processing Record 44 of Set 9 | waipawa
# Processing Record 45 of Set 9 | hambantota
# Processing Record 46 of Set 9 | rio grande
# Processing Record 47 of Set 9 | charters towers
# Processing Record 48 of Set 9 | yugorsk
# Processing Record 49 of Set 9 | san quintin
# Processing Record 50 of Set 9 | olafsvik
# Processing Record 1 of Set 10 | seoul
# Processing Record 2 of Set 10 | madang
# Processing Record 3 of Set 10 | rabo de peixe
# Processing Record 4 of Set 10 | khandbari
# Processing Record 5 of Set 10 | kahului
# Processing Record 6 of Set 10 | marsh harbour
# Processing Record 7 of Set 10 | srandakan
# Processing Record 8 of Set 10 | inhambane
# Processing Record 9 of Set 10 | muisne
# Processing Record 10 of Set 10 | guerrero negro
# Processing Record 11 of Set 10 | kirakira
# Processing Record 12 of Set 10 | yueyang
# Processing Record 13 of Set 10 | sugod
# Processing Record 14 of Set 10 | ihosy
# Processing Record 15 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 10 | taoudenni
# Processing Record 17 of Set 10 | taltal
# Processing Record 18 of Set 10 | zaoyang
# Processing Record 19 of Set 10 | husavik
# Processing Record 20 of Set 10 | nabire
# Processing Record 21 of Set 10 | penukonda
# Processing Record 22 of Set 10 | muros
# Processing Record 23 of Set 10 | vila velha
# Processing Record 24 of Set 10 | tommot
# Processing Record 25 of Set 10 | makat
# Processing Record 26 of Set 10 | alice
# Processing Record 27 of Set 10 | jalu
# Processing Record 28 of Set 10 | port macquarie
# Processing Record 29 of Set 10 | ferrol
# Processing Record 30 of Set 10 | singaraja
# Processing Record 31 of Set 10 | santa cruz cabralia
# Processing Record 32 of Set 10 | kembe
# Processing Record 33 of Set 10 | ponnani
# Processing Record 34 of Set 10 | portobelo
# Processing Record 35 of Set 10 | sangar
# Processing Record 36 of Set 10 | turtas
# Processing Record 37 of Set 10 | changji
# Processing Record 38 of Set 10 | suntar
# Processing Record 39 of Set 10 | saint-pierre
# Processing Record 40 of Set 10 | yarmouth
# Processing Record 41 of Set 10 | sterlibashevo
# Processing Record 42 of Set 10 | sfantu gheorghe
# Processing Record 43 of Set 10 | tuzah
# Processing Record 44 of Set 10 | sorong
# Processing Record 45 of Set 10 | nyurba
# Processing Record 46 of Set 10 | opuwo
# Processing Record 47 of Set 10 | bac lieu
# Processing Record 48 of Set 10 | fresnillo
# Processing Record 49 of Set 10 | koupela
# Processing Record 50 of Set 10 | kieta
# Processing Record 1 of Set 11 | tevaitoa
# Processing Record 2 of Set 11 | nacala
# Processing Record 3 of Set 11 | san patricio
# Processing Record 4 of Set 11 | russkiy aktash
# Processing Record 5 of Set 11 | mujiayingzi
# Processing Record 6 of Set 11 | russell
# Processing Record 7 of Set 11 | waslala
# Processing Record 8 of Set 11 | hirara
# Processing Record 9 of Set 11 | puerto baquerizo moreno
# Processing Record 10 of Set 11 | penarroya-pueblonuevo
# Processing Record 11 of Set 11 | dabola
# Processing Record 12 of Set 11 | port-gentil
# Processing Record 13 of Set 11 | agadez
# Processing Record 14 of Set 11 | kidal
# Processing Record 15 of Set 11 | ransang
# Processing Record 16 of Set 11 | moorhead
# Processing Record 17 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 11 | si racha
# Processing Record 19 of Set 11 | kavieng
# Processing Record 20 of Set 11 | nishihara
# Processing Record 21 of Set 11 | rechitsy
# Processing Record 22 of Set 11 | japura
# Processing Record 23 of Set 11 | guayaramerin
# Processing Record 24 of Set 11 | ornskoldsvik
# Processing Record 25 of Set 11 | bangor
# Processing Record 26 of Set 11 | morondava
# Processing Record 27 of Set 11 | farkhor
# Processing Record 28 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 11 | shibarghan
# City not found. Skipping...
# Processing Record 30 of Set 11 | buin
# Processing Record 31 of Set 11 | kapoeta
# Processing Record 32 of Set 11 | carnduff
# Processing Record 33 of Set 11 | owando
# Processing Record 34 of Set 11 | carikar
# City not found. Skipping...
# Processing Record 35 of Set 11 | gorazde
# Processing Record 36 of Set 11 | calabozo
# Processing Record 37 of Set 11 | istok
# Processing Record 38 of Set 11 | samana
# Processing Record 39 of Set 11 | grimari
# City not found. Skipping...
# Processing Record 40 of Set 11 | grenville
# Processing Record 41 of Set 11 | aksu
# Processing Record 42 of Set 11 | el fuerte
# Processing Record 43 of Set 11 | itacarambi
# Processing Record 44 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 45 of Set 11 | san miguel
# Processing Record 46 of Set 11 | liuzhou
# Processing Record 47 of Set 11 | juba
# Processing Record 48 of Set 11 | severnyy
# Processing Record 49 of Set 11 | hamilton
# Processing Record 50 of Set 11 | azangaro
# Processing Record 1 of Set 12 | pochutla
# Processing Record 2 of Set 12 | mzimba
# Processing Record 3 of Set 12 | aksarka
# Processing Record 4 of Set 12 | terre haute
# Processing Record 5 of Set 12 | nemuro
# Processing Record 6 of Set 12 | henties bay
# Processing Record 7 of Set 12 | wildomar
# Processing Record 8 of Set 12 | almeirim
# Processing Record 9 of Set 12 | rovaniemi
# Processing Record 10 of Set 12 | sakakah
# Processing Record 11 of Set 12 | hanumangarh
# Processing Record 12 of Set 12 | mega
# Processing Record 13 of Set 12 | korgen
# Processing Record 14 of Set 12 | codrington
# Processing Record 15 of Set 12 | haverfordwest
# Processing Record 16 of Set 12 | kuryk
# Processing Record 17 of Set 12 | nsanje
# Processing Record 18 of Set 12 | golden
# Processing Record 19 of Set 12 | silver city
# Processing Record 20 of Set 12 | jamshedpur
# Processing Record 21 of Set 12 | lompoc
# Processing Record 22 of Set 12 | filadelfia
# Processing Record 23 of Set 12 | beloha
# Processing Record 24 of Set 12 | mosquera
# Processing Record 25 of Set 12 | troitsko-pechorsk
# Processing Record 26 of Set 12 | salalah
# Processing Record 27 of Set 12 | kayerkan
# Processing Record 28 of Set 12 | voh
# Processing Record 29 of Set 12 | shirokiy
# Processing Record 30 of Set 12 | alta gracia
# Processing Record 31 of Set 12 | lethem
# Processing Record 32 of Set 12 | isabela
# Processing Record 33 of Set 12 | kiama
# Processing Record 34 of Set 12 | cap-aux-meules
# Processing Record 35 of Set 12 | volos
# Processing Record 36 of Set 12 | suzdal
# Processing Record 37 of Set 12 | washougal
# Processing Record 38 of Set 12 | pamekasan
# Processing Record 39 of Set 12 | mizdah
# Processing Record 40 of Set 12 | pampa
# Processing Record 41 of Set 12 | oksfjord
# Processing Record 42 of Set 12 | prainha
# Processing Record 43 of Set 12 | tamana
# Processing Record 44 of Set 12 | upata
# Processing Record 45 of Set 12 | pacific grove
# Processing Record 46 of Set 12 | morada nova
# Processing Record 47 of Set 12 | aurad
# Processing Record 48 of Set 12 | ler
# Processing Record 49 of Set 12 | gamba
# Processing Record 50 of Set 12 | ahipara
# Processing Record 1 of Set 13 | ecoporanga
# Processing Record 2 of Set 13 | lagoa
# Processing Record 3 of Set 13 | sibolga
# Processing Record 4 of Set 13 | kralendijk
# Processing Record 5 of Set 13 | baykit
# Processing Record 6 of Set 13 | lasa
# Processing Record 7 of Set 13 | san francisco del mar
# Processing Record 8 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 13 | casino
# Processing Record 10 of Set 13 | egvekinot
# Processing Record 11 of Set 13 | nidadavole
# Processing Record 12 of Set 13 | oranjemund
# Processing Record 13 of Set 13 | saint-augustin
# Processing Record 14 of Set 13 | obo
# Processing Record 15 of Set 13 | polyarnyy
# Processing Record 16 of Set 13 | hay river
# Processing Record 17 of Set 13 | hanzhong
# Processing Record 18 of Set 13 | jumla
# Processing Record 19 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 13 | towada
# Processing Record 21 of Set 13 | manono
# Processing Record 22 of Set 13 | buala
# Processing Record 23 of Set 13 | igarka
# Processing Record 24 of Set 13 | ixtapa
# Processing Record 25 of Set 13 | thai binh
# Processing Record 26 of Set 13 | mildura
# Processing Record 27 of Set 13 | weyburn
# Processing Record 28 of Set 13 | kemijarvi
# Processing Record 29 of Set 13 | ucluelet
# Processing Record 30 of Set 13 | monduli
# Processing Record 31 of Set 13 | yei
# Processing Record 32 of Set 13 | nicolet
# Processing Record 33 of Set 13 | lugovoy
# Processing Record 34 of Set 13 | madison
# Processing Record 35 of Set 13 | xuanhua
# Processing Record 36 of Set 13 | mossendjo
# Processing Record 37 of Set 13 | sept-iles
# Processing Record 38 of Set 13 | miguel hidalgo
# Processing Record 39 of Set 13 | kutum
# Processing Record 40 of Set 13 | nola
# Processing Record 41 of Set 13 | tavricheskoye
# Processing Record 42 of Set 13 | graham
# Processing Record 43 of Set 13 | voi
# Processing Record 44 of Set 13 | paamiut
# Processing Record 45 of Set 13 | kariba
# Processing Record 46 of Set 13 | eha amufu
# Processing Record 47 of Set 13 | matelandia
# Processing Record 48 of Set 13 | margate
# Processing Record 49 of Set 13 | linfen
# Processing Record 50 of Set 13 | pemangkat
# Processing Record 1 of Set 14 | arkhangelsk
# Processing Record 2 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 14 | kurtamysh
# Processing Record 4 of Set 14 | esperantinopolis
# Processing Record 5 of Set 14 | palmer
# Processing Record 6 of Set 14 | busayra
# Processing Record 7 of Set 14 | sobolevo
# Processing Record 8 of Set 14 | laurel
# Processing Record 9 of Set 14 | bitung
# Processing Record 10 of Set 14 | konya
# Processing Record 11 of Set 14 | ostrovnoy
# Processing Record 12 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 14 | viedma
# Processing Record 14 of Set 14 | puerto del rosario
# Processing Record 15 of Set 14 | surt
# Processing Record 16 of Set 14 | norman wells
# Processing Record 17 of Set 14 | muroto
# Processing Record 18 of Set 14 | lumphat
# Processing Record 19 of Set 14 | la ronge
# Processing Record 20 of Set 14 | itarema
# Processing Record 21 of Set 14 | tupelo
# Processing Record 22 of Set 14 | gizo
# Processing Record 23 of Set 14 | milingimbi
# City not found. Skipping...
# Processing Record 24 of Set 14 | ust-kuyga
# Processing Record 25 of Set 14 | kagadi
# Processing Record 26 of Set 14 | veraval
# Processing Record 27 of Set 14 | kokorevka
# Processing Record 28 of Set 14 | soyo
# Processing Record 29 of Set 14 | los llanos de aridane
# Processing Record 30 of Set 14 | constantine
# Processing Record 31 of Set 14 | seabra
# Processing Record 32 of Set 14 | roudnice
# Processing Record 33 of Set 14 | general roca
# Processing Record 34 of Set 14 | bilma
# Processing Record 35 of Set 14 | phan thiet
# Processing Record 36 of Set 14 | fernandez
# Processing Record 37 of Set 14 | goderich
# Processing Record 38 of Set 14 | te anau
# Processing Record 39 of Set 14 | berezovyy
# Processing Record 40 of Set 14 | ambon
# Processing Record 41 of Set 14 | prince rupert
# Processing Record 42 of Set 14 | sayyan
# Processing Record 43 of Set 14 | port-cartier
# Processing Record 44 of Set 14 | ningxiang
# Processing Record 45 of Set 14 | ust-ishim
# Processing Record 46 of Set 14 | severnoye
# Processing Record 47 of Set 14 | ivanivka
# Processing Record 48 of Set 14 | tiznit
# Processing Record 49 of Set 14 | maraa
# Processing Record 50 of Set 14 | pompeu
# Processing Record 1 of Set 15 | gaoyou
# Processing Record 2 of Set 15 | hirtshals
# Processing Record 3 of Set 15 | udachnyy
# Processing Record 4 of Set 15 | saint-francois
# Processing Record 5 of Set 15 | lingyuan
# Processing Record 6 of Set 15 | moose factory
# Processing Record 7 of Set 15 | garissa
# Processing Record 8 of Set 15 | camocim
# Processing Record 9 of Set 15 | bongouanou
# Processing Record 10 of Set 15 | barranca
# Processing Record 11 of Set 15 | mumford
# Processing Record 12 of Set 15 | moron
# Processing Record 13 of Set 15 | pedernales
# Processing Record 14 of Set 15 | montepuez
# Processing Record 15 of Set 15 | mardin
# Processing Record 16 of Set 15 | cockburn town
# Processing Record 17 of Set 15 | alihe
# Processing Record 18 of Set 15 | temir
# Processing Record 19 of Set 15 | yatou
# Processing Record 20 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 15 | kaka
# Processing Record 22 of Set 15 | neyshabur
# Processing Record 23 of Set 15 | tambul
# City not found. Skipping...
# Processing Record 24 of Set 15 | manikchhari
# City not found. Skipping...
# Processing Record 25 of Set 15 | iskateley
# Processing Record 26 of Set 15 | qaqortoq
# Processing Record 27 of Set 15 | tshane
# Processing Record 28 of Set 15 | aykhal
# Processing Record 29 of Set 15 | dicabisagan
# Processing Record 30 of Set 15 | santa isabel do rio negro
# Processing Record 31 of Set 15 | santa fe
# Processing Record 32 of Set 15 | sabha
# Processing Record 33 of Set 15 | ukhta
# Processing Record 34 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 35 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 15 | plettenberg bay
# Processing Record 37 of Set 15 | sao gabriel
# Processing Record 38 of Set 15 | mitzic
# Processing Record 39 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 15 | uryupinsk
# Processing Record 41 of Set 15 | keskin
# Processing Record 42 of Set 15 | tibacuy
# Processing Record 43 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 15 | leh
# Processing Record 45 of Set 15 | tucuma
# Processing Record 46 of Set 15 | snezhnogorsk
# Processing Record 47 of Set 15 | champerico
# Processing Record 48 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 15 | key largo
# Processing Record 50 of Set 15 | cuiluan
# Processing Record 1 of Set 16 | portland
# Processing Record 2 of Set 16 | arman
# Processing Record 3 of Set 16 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 16 | garowe
# Processing Record 5 of Set 16 | muscat
# Processing Record 6 of Set 16 | kavaratti
# Processing Record 7 of Set 16 | chicama
# Processing Record 8 of Set 16 | coutances
# Processing Record 9 of Set 16 | okhotsk
# Processing Record 10 of Set 16 | lockhart
# Processing Record 11 of Set 16 | scarborough
# Processing Record 12 of Set 16 | urumqi
# Processing Record 13 of Set 16 | george
# Processing Record 14 of Set 16 | kinsale
# Processing Record 15 of Set 16 | svetlaya
# Processing Record 16 of Set 16 | yugo-kamskiy
# Processing Record 17 of Set 16 | mizan teferi
# Processing Record 18 of Set 16 | yaan
# Processing Record 19 of Set 16 | artyom
# Processing Record 20 of Set 16 | palembang
# Processing Record 21 of Set 16 | bermeo
# Processing Record 22 of Set 16 | carutapera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Hermanus -34.4187   19.2345     72.81        70          39        6.80
# 1   Ushuaia -54.8000  -68.3000     42.46        56         100       17.27
# 2    Alizai  33.5383   70.3462     90.88        21          65       16.93
# 3   Rikitea -23.1203 -134.9692     77.54        74          87       15.17
# 4  Shizunai  42.3339  142.3669     45.45        77          77       13.13
# 5      Sola -13.8833  167.5500     75.87       100          20        0.00
# 6      Chuy -33.6971  -53.4616     55.00        74          33        7.81
# 7     Bluff -46.6000  168.3333     53.80        83          43        6.96
# 8    Hasaki  35.7333  140.8333     57.29        58           6       10.65
# 9     Airai  -8.9266  125.4092     62.01        87          67        2.84
#
#   Country Current Description
# 0      ZA    scattered clouds
# 1      AR     overcast clouds
# 2      PK       broken clouds
# 3      PF     overcast clouds
# 4      JP       broken clouds
# 5      VU          few clouds
# 6      UY    scattered clouds
# 7      NZ    scattered clouds
# 8      JP           clear sky
# 9      TL       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.4187   19.2345     72.81        70          39
# 1       Ushuaia      AR -54.8000  -68.3000     42.46        56         100
# 2        Alizai      PK  33.5383   70.3462     90.88        21          65
# 3       Rikitea      PF -23.1203 -134.9692     77.54        74          87
# 4      Shizunai      JP  42.3339  142.3669     45.45        77          77
# ..          ...     ...      ...       ...       ...       ...         ...
# 710        Yaan      NG   7.3833    8.5667     86.76        57         100
# 711      Artyom      AZ  40.4723   50.3330     62.74        69          90
# 712   Palembang      ID  -2.9167  104.7458     82.49        74          40
# 713      Bermeo      ES  43.4209   -2.7215     60.49        75          98
# 714  Carutapera      BR  -1.1950  -46.0200     75.36        95          99
#
#      Wind Speed Current Description
# 0          6.80    scattered clouds
# 1         17.27     overcast clouds
# 2         16.93       broken clouds
# 3         15.17     overcast clouds
# 4         13.13       broken clouds
# ..          ...                 ...
# 710        2.28     overcast clouds
# 711       24.16     overcast clouds
# 712       10.36    scattered clouds
# 713       17.13     overcast clouds
# 714        2.91     overcast clouds
#
# [715 rows x 9 columns]

# %%
#create the output file (CSV).
output_data_file = "C:/Users/Elissa/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
#export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
